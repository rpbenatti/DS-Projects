# %% [markdown]
# # Landslide Datasets

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Global Landslide Catalog (GLC) - Kaggle Dataset
# (compiled since 2007 at NASA Goddard Space Flight Center)

# %% [markdown]
# Landslides After Rainfall, 2007-2016
# Location and cause of landslide events around the world
#
# NASA
# - updated 3 years ago (Version 1)
#
# https://www.kaggle.com/nasa/landslide-events

# %% [markdown]
# Context
# Landslides are one of the most pervasive hazards in the world, causing more than 11,500 fatalities in 70 countries since 2007. Saturating the soil on vulnerable slopes, intense and prolonged rainfall is the most frequent landslide trigger.
#
# Content
# The Global Landslide Catalog (GLC) was developed with the goal of identifying rainfall-triggered landslide events around the world, regardless of size, impacts, or location. The GLC considers all types of mass movements triggered by rainfall, which have been reported in the media, disaster databases, scientific reports, or other sources.
#
# Acknowledgements
# The GLC has been compiled since 2007 at NASA Goddard Space Flight Center.

# %% [markdown]
# Data Sources
# catalog.csv   23 columns
#
# About this file
# Landslide events caused by rainfall
#
# Columns
#
# - id
# - date
# - time
# - continent_code
# - country_name
# - country_code
# - state/province
# - population
# - city/town
# - distance
# - location_description
# - latitude
# - longitude
# - geolocation
# - hazard_type
# - landslide_type
# - landslide_size
# - trigger
# - storm_name
# - injuries
# - fatalities
# - source_name
# - source_link

# %%
ls_glc_nasa = pd.read_csv(r'Datasets/catalog.csv')

# %% [markdown]
# **Checking dataset information - Features and ammount of data**

# %%
ls_glc_nasa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1693 entries, 0 to 1692
# Data columns (total 23 columns):
# id                      1693 non-null int64
# date                    1690 non-null object
# time                    629 non-null object
# continent_code          164 non-null object
# country_name            1693 non-null object
# country_code            1693 non-null object
# state/province          1692 non-null object
# population              1693 non-null int64
# city/town               1689 non-null object
# distance                1692 non-null float64
# location_description    551 non-null object
# latitude                1692 non-null float64
# longitude               1692 non-null float64
# geolocation             1692 non-null object
# hazard_type             1693 non-null object
# landslide_type          1692 non-null object
# landslide_size          1692 non-null object
# trigger                 1691 non-null object
# ...

# %% [markdown]
# **Data starts in 2007/Mar up to 2016/Mar**

# %%
ls_glc_nasa.head()
# Out:
#    id     date   time continent_code   country_name country_code  \
# 0  34   3/2/07  Night            NaN  United States           US
# 1  42  3/22/07    NaN            NaN  United States           US
# 2  56   4/6/07    NaN            NaN  United States           US
# 3  59  4/14/07    NaN            NaN         Canada           CA
# 4  61  4/15/07    NaN            NaN  United States           US
#
#   state/province  population         city/town  distance location_description  \
# 0       Virginia       16000       Cherry Hill   3.40765              Unknown
# 1           Ohio       17288  New Philadelphia   3.33522                  NaN
# 2   Pennsylvania       15930       Wilkinsburg   2.91977           Urban area
# 3         Quebec       42786       Châteauguay   2.98682          Above river
# 4       Kentucky        6903         Pikeville   5.66542           Below road
#
#    latitude  longitude                                geolocation hazard_type  \
# ...

# %%
ls_glc_nasa.tail()
# Out:
#         id     date   time continent_code   country_name country_code  \
# 1688  7535  12/7/15    NaN            NaN  United States           US
# 1689  7537  2/22/16   0:00            NaN  United States           US
# 1690  7539  2/23/16    NaN            NaN  United States           US
# 1691  7540  2/26/16  21:06            NaN  United States           US
# 1692  7541   3/2/16   8:00            NaN  United States           US
#
#       state/province  population   city/town  distance location_description  \
# 1688  North Carolina        1646       Tryon   7.80866           Above road
# 1689   West Virginia       51400  Charleston   6.84721        Natural slope
# 1690   West Virginia        2406       Welch  14.19735           Above road
# 1691   West Virginia        1048      Athens  12.00678           Above road
# 1692         Vermont        2066     Windsor   1.78429           Above road
#
#       latitude  longitude                                geolocation  \
# ...

# %% [markdown]
# **Landslide by Countries**

# %%
ls_glc_nasa.country_name.value_counts()
# Out:
# United States                       986
# Colombia                             96
# Guatemala                            79
# Costa Rica                           75
# Mexico                               73
# Trinidad and Tobago                  63
# Panama                               40
# Honduras                             38
# Jamaica                              33
# Nicaragua                            31
# Ecuador                              30
# El Salvador                          22
# Haiti                                20
# Venezuela                            20
# Dominican Republic                   15
# Dominica                             14
# Peru                                 14
# Canada                               10
# Saint Lucia                           8
# Puerto Rico                           7
# Brazil                                4
# Saint Vincent and the Grenadines      4
# Cuba                                  3
# ...

# %% [markdown]
# **Landslides reported in Brazil**

# %%
ls_glc_nasa[(ls_glc_nasa.country_code == 'BR')]
# Out:
#         id     date     time continent_code country_name country_code  \
# 192   1019   5/6/09      NaN             SA       Brazil           BR
# 193   1020   5/6/09      NaN             SA       Brazil           BR
# 946   4789  3/28/13  0:30:00             SA       Brazil           BR
# 1347  6591   1/4/14      NaN             SA       Brazil           BR
#
#      state/province  population       city/town  distance  \
# 192            Pará       70888        Altamira   1.01848
# 193        Maranhão       48901  Barra do Corda  61.75306
# 946           Amapá       83927         Santana   0.17020
# 1347           Pará       78050      Abaetetuba   1.04062
#
#      location_description  latitude  longitude  \
# 192                   NaN   -3.1946   -52.2093
# 193                   NaN   -5.0804   -45.6010
# 946                   NaN   -0.0568   -51.1818
# 1347           Urban area   -1.7225   -48.8907
#
#                                        geolocation hazard_type  \
# ...

# %% [markdown]
# **Landslide Types**

# %%
ls_glc_nasa.hazard_type.value_counts()
# Out:
# Landslide    1693
# Name: hazard_type, dtype: int64

# %%
ls_glc_nasa.landslide_type.value_counts()
# Out:
# Landslide             866
# Mudslide              635
# Rockfall               70
# Complex                48
# Debris flow            38
# Other                  14
# Riverbank collapse      5
# Creep                   5
# mudslide                4
# Lahar                   2
# Snow avalanche          2
# landslide               1
# Unknown                 1
# Rockslide               1
# Name: landslide_type, dtype: int64

# %% [markdown]
# **Landslide Sizes**

# %%
ls_glc_nasa.landslide_size.value_counts()
# Out:
# Medium        965
# Small         636
# Large          68
# Very_large     15
# medium          3
# small           3
# large           2
# Name: landslide_size, dtype: int64

# %% [markdown]
# **Landslide Triggers**

# %%
ls_glc_nasa.trigger.value_counts()
# Out:
# Downpour                   866
# Rain                       446
# Tropical cyclone           131
# Continuous rain             95
# Unknown                     88
# unknown                     12
# Snowfall snowmelt           11
# Flooding                    10
# Earthquake                   8
# Mining digging               7
# Freeze thaw                  6
# Construction                 5
# Other                        3
# downpour                     1
# Volcano                      1
# Dam embankment collapse      1
# Name: trigger, dtype: int64

# %% [markdown]
# ## National Emergency Management Information System - Kaggle Dataset
# (Federal Emergency Management Agency - FEMA - with data from the National Emergency Management Information System)

# %% [markdown]
# Federal Emergencies and Disasters, 1953-Present
#
# Has the number of emergencies declared by the president risen over time?
#
# Federal Emergency Management Agency (FEMA)
# - updated 3 years ago (Version 1)

# %% [markdown]
# Context
# The president can declare an emergency for any occasion or instance when the President determines federal assistance is needed. Emergency declarations supplement State and local or Indian tribal government efforts in providing emergency services, such as the protection of lives, property, public health, and safety, or to lessen or avert the threat of a catastrophe in any part of the United States. The total amount of assistance provided for in a single emergency may not exceed $5 million.
#
# Content
# This dataset includes a record for every federal emergency or disaster declared by the President of the United States since 1953.
#
# Acknowledgements
# The disaster database was published by the Federal Emergency Management Agency with data from the National Emergency Management Information System.
#
# Inspiration
# What type of disaster is the most commonly declared by FEMA? Which disasters or emergencies have lasted the longest? What disaster was declared in the most counties or states? Has the number of disasters declared by FEMA risen or fallen over time?
# The president can declare a major disaster for any natural event, including any hurricane, tornado, storm, high water, wind-driven water, tidal wave, tsunami, earthquake, volcanic eruption, landslide, mudslide, snowstorm, or drought, or, regardless of cause, fire, flood, or explosion, that the President determines has caused damage of such severity that it is beyond the combined capabilities of state and local governments to respond. A major disaster declaration provides a wide range of federal assistance programs for individuals and public infrastructure, including funds for both emergency and permanent work.

# %% [markdown]
# Data Sources
# database.csv - 14 columns
#
# About this file
# Federal emergencies and disasters
#
# Columns
#
# - Declaration Number
# - Declaration Type
# - Declaration Date
# - State
# - County
# - Disaster Type
# - Disaster Title
# - Start Date
# - End Date
# - Close Date
# - Individual Assistance Program
# - Individuals & Households Program
# - Public Assistance Program
# - Hazard Mitigation Program

# %%
ls_fema = pd.read_csv(r'Datasets/database.csv')

# %% [markdown]
# **Checking dataset information - Features and ammount of data**

# %%
ls_fema.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46185 entries, 0 to 46184
# Data columns (total 14 columns):
# Declaration Number                  46185 non-null object
# Declaration Type                    46185 non-null object
# Declaration Date                    46185 non-null object
# State                               46185 non-null object
# County                              45988 non-null object
# Disaster Type                       46185 non-null object
# Disaster Title                      46185 non-null object
# Start Date                          46185 non-null object
# End Date                            45843 non-null object
# Close Date                          35210 non-null object
# Individual Assistance Program       46185 non-null object
# Individuals & Households Program    46185 non-null object
# Public Assistance Program           46185 non-null object
# Hazard Mitigation Program           46185 non-null object
# dtypes: object(14)
# memory usage: 4.9+ MB

# %% [markdown]
# **Data starts in 1953/May up to 2017/Feb**

# %%
ls_fema.head()
# Out:
#   Declaration Number Declaration Type Declaration Date State County  \
# 0               DR-1         Disaster       05/02/1953    GA    NaN
# 1               DR-2         Disaster       05/15/1953    TX    NaN
# 2               DR-3         Disaster       05/29/1953    LA    NaN
# 3               DR-4         Disaster       06/02/1953    MI    NaN
# 4               DR-5         Disaster       06/06/1953    MT    NaN
#
#   Disaster Type              Disaster Title  Start Date    End Date  \
# 0       Tornado                     Tornado  05/02/1953  05/02/1953
# 1       Tornado  Tornado and Heavy Rainfall  05/15/1953  05/15/1953
# 2         Flood                       Flood  05/29/1953  05/29/1953
# 3       Tornado                     Tornado  06/02/1953  06/02/1953
# 4         Flood                      Floods  06/06/1953  06/06/1953
#
#    Close Date Individual Assistance Program Individuals & Households Program  \
# ...

# %%
ls_fema.tail()
# Out:
#       Declaration Number Declaration Type Declaration Date State  \
# 46180            DR-4301         Disaster       02/14/2017    CA
# 46181            DR-4301         Disaster       02/14/2017    CA
# 46182            DR-4301         Disaster       02/14/2017    CA
# 46183            DR-4301         Disaster       02/14/2017    CA
# 46184            DR-4301         Disaster       02/14/2017    CA
#
#                 County Disaster Type  \
# 46180    Sutter County         Storm
# 46181   Trinity County         Storm
# 46182  Tuolumne County         Storm
# 46183      Yolo County         Storm
# 46184      Yuba County         Storm
#
#                                       Disaster Title  Start Date    End Date  \
# 46180  Severe Winter Storms, Flooding, and Mudslides  01/03/2017  01/12/2017
# 46181  Severe Winter Storms, Flooding, and Mudslides  01/03/2017  01/12/2017
# 46182  Severe Winter Storms, Flooding, and Mudslides  01/03/2017  01/12/2017
# ...

# %% [markdown]
# **Disaster Types**

# %%
ls_fema['Disaster Type'].value_counts()
# Out:
# Storm              16250
# Flood               9317
# Hurricane           8764
# Snow                3565
# Fire                2647
# Ice                 1970
# Tornado             1412
# Drought             1292
# Winter               301
# Other                297
# Typhoon              119
# Earthquake           105
# Volcano               50
# Water                 42
# Chemical              18
# Mud/Landslide         10
# Tsunami                9
# Dam/Levee Break        6
# Human Cause            6
# Terrorism              5
# Name: Disaster Type, dtype: int64

# %%
ls_fema['Disaster Title'].value_counts()
# Out:
# Severe Storms and Flooding                                     6817
# Severe Storms, Tornadoes, and Flooding                         3229
# Hurricane Katrina Evacuation                                   2602
# Severe Winter Storm                                            1887
# Flooding                                                       1232
# Drought                                                        1014
# Severe Winter Storms                                            844
# Severe Storms, Tornadoes, Straight-Line Winds, and Flooding     827
# Wildfires                                                       610
# Snow                                                            602
# Heavy Rains and Flooding                                        595
# Severe Storms, Flooding, and Tornadoes                          573
# Severe Storms and Tornadoes                                     568
# Hurricane Sandy                                                 559
# ...

# %%
ls_fema[ls_fema['Disaster Title'].str.contains('Landslide')].head()
# Out:
#      Declaration Number Declaration Type Declaration Date State  \
# 1708             DR-281         Disaster       12/19/1969    AK
# 3291             DR-396         Disaster       07/06/1973    CO
# 3292             DR-396         Disaster       07/06/1973    CO
# 3293             DR-396         Disaster       07/06/1973    CO
# 3294             DR-396         Disaster       07/06/1973    CO
#
#                 County Disaster Type             Disaster Title  Start Date  \
# 1708  Tanana ANV/ANVSA         Storm  Heavy Rains and Landslide  12/19/1969
# 3291    Alamosa County         Flood    Flooding and Landslides  07/06/1973
# 3292  Archuleta County         Flood    Flooding and Landslides  07/06/1973
# 3293    Conejos County         Flood    Flooding and Landslides  07/06/1973
# 3294   Costilla County         Flood    Flooding and Landslides  07/06/1973
#
#         End Date  Close Date Individual Assistance Program  \
# 1708  12/19/1969  08/16/1971                           Yes
# ...

# %% [markdown]
# ## Natural disaster data - Kaggle

# %% [markdown]
# Content
# This dataset contains information on global occurrences of natural disasters and the economic damage caused by them. The included types of natural disaster are 'Drought', 'Earthquake', 'Extreme temperature', 'Extreme weather', 'Flood', 'Impact', 'Landslide', 'Mass movement (dry)', 'Volcanic activity' and 'Wildfire'. It also includes information on all these natural disasters combined. The time period is 1900-2018 with several missing values.
#
# This dataset is a subset of the data available on https://ourworldindata.org/natural-disasters
#
# Acknowledgements
# Thanks to https://ourworldindata.org/natural-disasters (data published by EMDAT (2019): OFDA/CRED International Disaster Database, Université catholique de Louvain – Brussels – Belgium) for the data.
#
# Other links:
#
# https://ourworldindata.org/ofdacred-international-disaster-data
# https://ourworldindata.org/natural-disasters

# %% [markdown]
# Data Sources
# economic-damage-from-natural-disasters.csv - 4 columns
# number-of-natural-disaster-events.csv - 4 columns
#
# About this file
# No description yet
#
# Columns
# - Entity
# - Code
# - Year
# - Total economic damage from natural disasters (US$)

# %%
ls_ourworldindata_economic = pd.read_csv(r'Datasets/economic-damage-from-natural-disasters.csv')
ls_ourworldindata_numbers = pd.read_csv(r'Datasets/number-of-natural-disaster-events.csv')

# %%
ls_ourworldindata_economic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 4 columns):
# Entity                                                561 non-null object
# Code                                                  0 non-null float64
# Year                                                  561 non-null int64
# Total economic damage from natural disasters (US$)    561 non-null int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 17.6+ KB

# %%
ls_ourworldindata_economic.head()
# Out:
#                   Entity  Code  Year  \
# 0  All natural disasters   NaN  1900
# 1  All natural disasters   NaN  1901
# 2  All natural disasters   NaN  1902
# 3  All natural disasters   NaN  1903
# 4  All natural disasters   NaN  1904
#
#    Total economic damage from natural disasters (US$)
# 0                                           30000000
# 1                                                  0
# 2                                                  0
# 3                                          480000000
# 4                                                  0

# %%
ls_ourworldindata_economic.tail()
# Out:
#        Entity  Code  Year  Total economic damage from natural disasters (US$)
# 556  Wildfire   NaN  2014                                          259000000
# 557  Wildfire   NaN  2015                                         3439820000
# 558  Wildfire   NaN  2016                                         6287000000
# 559  Wildfire   NaN  2017                                         1019000000
# 560  Wildfire   NaN  2018                                        22745000000

# %%
ls_ourworldindata_numbers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 828 entries, 0 to 827
# Data columns (total 4 columns):
# Entity                                                       828 non-null object
# Code                                                         0 non-null float64
# Year                                                         828 non-null int64
# Number of reported natural disasters (reported disasters)    828 non-null int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 26.0+ KB

# %%
ls_ourworldindata_numbers.head()
# Out:
#                   Entity  Code  Year  \
# 0  All natural disasters   NaN  1900
# 1  All natural disasters   NaN  1901
# 2  All natural disasters   NaN  1902
# 3  All natural disasters   NaN  1903
# 4  All natural disasters   NaN  1904
#
#    Number of reported natural disasters (reported disasters)
# 0                                                  5
# 1                                                  2
# 2                                                  9
# 3                                                  8
# 4                                                  2

# %%
ls_ourworldindata_numbers.tail()
# Out:
#        Entity  Code  Year  \
# 823  Wildfire   NaN  2014
# 824  Wildfire   NaN  2015
# 825  Wildfire   NaN  2016
# 826  Wildfire   NaN  2017
# 827  Wildfire   NaN  2018
#
#      Number of reported natural disasters (reported disasters)
# 823                                                  4
# 824                                                 12
# 825                                                 10
# 826                                                 13
# 827                                                 10

# %% [markdown]
# ## Cooperative Open Online Landslide Repository
# (Western Pennsylvania Regional Data Center - WPRDC)

# %% [markdown]
# https://data.wprdc.org/dataset/landslides
#
# Landslides
# From NASA's Cooperative Open Online Landslide Repository (COOLR).
#
# The Cooperative Open Online Landslide Repository (COOLR) is a worldwide database of landslide events. It currently includes NASA’s Global Landslide Catalog (GLC) and landslide events contributed by citizen scientists. In a future release of COOLR, collated landslide inventories will be added by REST API or manually.

# %%
ls_coolr = pd.read_csv(r'Datasets/globallandslides.csv')

# %% [markdown]
# **Checking dataset information - Features and ammount of data**

# %%
ls_coolr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11337 entries, 0 to 11336
# Data columns (total 29 columns):
# src_name      11337 non-null object
# src_link      10529 non-null object
# ev_id         11337 non-null object
# ev_date       11337 non-null object
# ev_time       5158 non-null object
# ev_title      11336 non-null object
# ev_desc       10473 non-null object
# loc_desc      11237 non-null object
# loc_accu      11335 non-null object
# ls_cat        11335 non-null object
# ls_trig       11304 non-null object
# ls_size       11327 non-null object
# ls_setting    11258 non-null object
# fatalities    11337 non-null object
# injuries      11337 non-null int64
# storm_name    576 non-null object
# photo_link    1672 non-null object
# comments      364 non-null object
# ev_imp_src    11337 non-null object
# ev_imp_id     9469 non-null float64
# latitude      11337 non-null float64
# longitude     11337 non-null float64
# ctry_name     11297 non-null object
# ...

# %% [markdown]
# **Data starts in 1988/Nov up to 2018/Jun**

# %%
ls_coolr.sort_values(by=['ev_date', 'ev_time'], ascending=True).head(3)
# Out:
#                        src_name  \
# 513   Philippine Daily Inquirer
# 5798                        BGS
# 6437                   24heures
#
#                                                src_link  ev_id     ev_date  \
# 513   http://newsinfo.inquirer.net/655816/landslide-...  6,436  1988-11-07
# 5798  http://britgeoheritage.blogspot.com/2015/08/la...  7,331  1993-06-04
# 6437  http://www.24heures.ch/vaud-regions/Le-petit-P...  7,408  1995-08-14
#
#      ev_time                          ev_title  \
# 513      NaN                 Sta. Rosa del Sur
# 5798   06:00                Holbeck Hall Hotel
# 6437   00:00  Caux : 50 000 m3 of debris flows
#
#                                                 ev_desc            loc_desc  \
# 513   He recalled that on Nov.7, 1988, 18 families w...   Sta. Rosa del Sur
# 5798  The first signs of movement on the cliff were ...  Holbeck Hall Hotel
# 6437                          50 000 m3 of debris flows                 NaN
#
# ...

# %%
ls_coolr.sort_values(by=['ev_date', 'ev_time'], ascending=True).tail(3)
# Out:
#                src_name                                           src_link  \
# 586   NorthEast India24  http://www.northeastindia24.com/mizoram-21-kil...
# 3659         The Nation  http://www.nationmultimedia.com/detail/breakin...
# 6020      Viet Nam News  http://vietnamnews.vn/society/449321/landslide...
#
#        ev_id     ev_date ev_time  \
# 586   11,530  2018-06-05   18:00
# 3659  11,524  2018-06-05     NaN
# 6020  11,533  2018-06-05     NaN
#
#                                           ev_title  \
# 586          Lunglawn Semi-pucca Building Mudslide
# 3659   Patong Road Landslide near U Zenmaya Phuket
# 6020  Highway No 174 Landslide in Yên Bái Province
#
#                                                 ev_desc  \
# 586   A mudslide triggered by heavy rains swept away...
# 3659  Heavy rains across Phuket on Tuesday morning c...
# 6020  Torrential rain between Monday night and early...
#
#                                                loc_desc loc_accu     ls_cat  \
# ...

# %% [markdown]
# **Landslide by Countries (Top 10)**

# %%
ls_coolr.ctry_name.value_counts().head(10)
# Out:
# United States     3691
# India             1532
# Philippines        729
# Nepal              558
# China              544
# Indonesia          410
# United Kingdom     264
# Canada             261
# Brazil             219
# Malaysia           209
# Name: ctry_name, dtype: int64

# %% [markdown]
# **Landslide reported in Brazil**

# %%
ls_coolr[(ls_coolr.ctry_code == 'BR')].head()
# Out:
#              src_name                                           src_link  \
# 73       Global Times     http://www.globaltimes.cn/content/910933.shtml
# 96    maps.google.com  http://maps.google.com.br/maps/ms?source=embed...
# 120   maps.google.com  http://maps.google.com.br/maps/ms?source=embed...
# 131  translate.google  http://translate.google.com/translate?js=n&pre...
# 181               CNN  http://www.cnn.com/2010/WORLD/americas/01/01/b...
#
#      ev_id     ev_date ev_time                          ev_title  \
# 73   6,849  2015-03-07   23:00               Santana do Parnaiba
# 96   1,634  2010-04-06     NaN  Morro dos Prazeres, Santa Teresa
# 120  1,664  2010-04-06     NaN               Estrada Fr. Orlando
# 131  2,972  2011-01-12     NaN    road RJ-116, Nova Friburgo, RJ
# 181  1,382  2010-01-01   04:00   Mudslide crushed the Sankay Inn
#
#                                                ev_desc  \
# 73   Three children were killed Saturday night when...
# ...

# %%
ls_coolr[(ls_coolr.ctry_code == 'BR')].shape
# Out:
# (219, 29)

# %%
ls_coolr[(ls_coolr.ctry_code == 'BR')].div_name.value_counts().plot.bar(figsize=(12,6));

# %% [markdown]
# **Landslide Types**

# %%
ls_coolr.ls_cat.value_counts()
# Out:
# landslide              7765
# mudslide               2183
# rock_fall               720
# complex                 235
# debris_flow             209
# other                    71
# riverbank_collapse       39
# unknown                  39
# translational_slide      20
# snow_avalanche           15
# creep                    12
# earth_flow               10
# lahar                     8
# rotational_slide          7
# topple                    2
# Name: ls_cat, dtype: int64

# %% [markdown]
# **Landslide Sizes**

# %%
ls_coolr.ls_size.value_counts()
# Out:
# medium          6651
# small           2901
# unknown          866
# large            797
# very_large       108
# catastrophic       4
# Name: ls_size, dtype: int64

# %% [markdown]
# **Landslide Triggers**

# %%
ls_coolr.ls_trig.value_counts()
# Out:
# downpour                   4772
# rain                       2689
# unknown                    1717
# continuous_rain             768
# tropical_cyclone            562
# snowfall_snowmelt           145
# monsoon                     130
# mining                       99
# earthquake                   93
# construction                 88
# flooding                     77
# no_apparent_trigger          57
# freeze_thaw                  43
# other                        35
# dam_embankment_collapse      13
# leaking_pipe                 13
# vibration                     2
# volcano                       1
# Name: ls_trig, dtype: int64

# %% [markdown]
# **Landslide - where it did occur**

# %%
ls_coolr.ls_setting.value_counts()
# Out:
# unknown             6314
# above_road          3234
# natural_slope        564
# urban                279
# below_road           230
# mine                 167
# above_river          154
# deforested_slope      65
# retaining_wall        57
# other                 53
# bluff                 53
# engineered_slope      34
# burned_area           32
# above_coast           22
# Name: ls_setting, dtype: int64
